# %% [markdown]
# --- Day 8: I Heard You Like Registers ---
#
# You receive a signal directly from the CPU. Because of your recent assistance with jump instructions, it would like you to compute the result of a series of unusual register instructions.
#
# Each instruction consists of several parts: the register to modify, whether to increase or decrease that register's value, the amount by which to increase or decrease it, and a condition. If the condition fails, skip the instruction without modifying the register. The registers all start at 0. The instructions look like this:
#
# b inc 5 if a > 1
# a inc 1 if b < 5
# c dec -10 if a >= 1
# c inc -20 if c == 10
# These instructions would be processed as follows:
#
# Because a starts at 0, it is not greater than 1, and so b is not modified.
# a is increased by 1 (to 1) because b is less than 5 (it is 0).
# c is decreased by -10 (to 10) because a is now greater than or equal to 1 (it is 1).
# c is increased by -20 (to -10) because c is equal to 10.
# After this process, the largest value in any register is 1.
#
# You might also encounter <= (less than or equal to) or != (not equal to). However, the CPU doesn't have the bandwidth to tell you what all the registers are named, and leaves that to you to determine.
#
# What is the largest value in any register after completing the instructions in your puzzle input?
#
# To begin, get your puzzle input.

# %%
with open("day8.txt") as f:
    data = f.readlines()

# %%
data[0:10]
# Out:
# ['g dec 231 if bfx > -10\n',
#  'k dec -567 if wfk == 0\n',
#  'jq inc 880 if a < 2\n',
#  'sh inc -828 if nkr < -5\n',
#  'w inc 595 if nkr > -10\n',
#  't dec 737 if bfx < 5\n',
#  'ghj dec -693 if pr == 0\n',
#  'yo inc -362 if t == -741\n',
#  'pr inc -851 if g <= -228\n',
#  'lpi inc 628 if lpi <= 0\n']

# %%
import pandas as pd

# %%
reg = [x.split(" ")[0] for x in data]
chng = [x.split(" ")[1] for x in data]
amt = [x.split(" ")[2] for x in data]
cond = [x.split(" if ")[1].strip("\n") for x in data]
comp_val = [x.split(" ")[-1] for x in cond]
comp_to = [x.split(" ")[0] for x in cond]
comp_op = [x.split(" ")[1] for x in cond]

# %%
df = pd.DataFrame({"register":reg, "change":chng, "amount":amt, "condition":cond, 
                   "compare_to":comp_to, "compare_op":comp_op, "compare_value":comp_val})

# %%
registers = df.register.unique()

# %%
registers
# Out:
# array(['g', 'k', 'jq', 'sh', 'w', 't', 'ghj', 'yo', 'pr', 'lpi', 'rlq',
#        'nkr', 'vh', 'afu', 'm', 'qrc', 'fkp', 'bfx', 'a', 'jh', 'ev',
#        'wfk', 'qn', 'qdq', 'u'], dtype=object)

# %%
current_amt = {}
for r in registers:
    current_amt[r] = 0

# %%
df.head(5)
# Out:
#   amount change compare_op compare_to compare_value  condition register
# 0    231    dec          >        bfx           -10  bfx > -10        g
# 1   -567    dec         ==        wfk             0   wfk == 0        k
# 2    880    inc          <          a             2      a < 2       jq
# 3   -828    inc          <        nkr            -5   nkr < -5       sh
# 4    595    inc          >        nkr           -10  nkr > -10        w

# %%
for i, r in df.iterrows():
    cv = current_amt[r['compare_to']]
    expression = str(cv) + " " + r['compare_op'] + " " + str(r['compare_value'])
    if eval(expression):
        if r['change'] == "inc":
            current_amt[r['register']] += float(r['amount'])
        elif r['change'] == "dec":
            current_amt[r['register']] -= float(r['amount'])
    print(
        r['condition'], 'evals to', expression,
        "and is", eval(expression), "so", r['change'], r['register'], "by", r['amount'], 
        "to get", current_amt[r['register']]

    )
# Out:
# bfx > -10 evals to 0 > -10 and is True so dec g by 231 to get -231.0
# wfk == 0 evals to 0 == 0 and is True so dec k by -567 to get 567.0
# a < 2 evals to 0 < 2 and is True so inc jq by 880 to get 880.0
# nkr < -5 evals to 0 < -5 and is False so inc sh by -828 to get 0
# nkr > -10 evals to 0 > -10 and is True so inc w by 595 to get 595.0
# bfx < 5 evals to 0 < 5 and is True so dec t by 737 to get -737.0
# pr == 0 evals to 0 == 0 and is True so dec ghj by -693 to get 693.0
# t == -741 evals to -737.0 == -741 and is False so inc yo by -362 to get 0
# g <= -228 evals to -231.0 <= -228 and is True so inc pr by -851 to get -851.0
# lpi <= 0 evals to 0 <= 0 and is True so inc lpi by 628 to get 628.0
# qn > -9 evals to 0 > -9 and is True so inc pr by -748 to get -1599.0
# k <= 574 evals to 567.0 <= 574 and is True so dec rlq by -290 to get 290.0
# wfk == -4 evals to 0 == -4 and is False so inc lpi by 252 to get 628.0
# bfx >= -7 evals to 0 >= -7 and is True so dec nkr by -674 to get 674.0
# fkp != 6 evals to 0 != 6 and is True so dec vh by 429 to get -429.0
# w <= 604 evals to 595.0 <= 604 and is True so dec w by 568 to get 27.0
# vh >= -438 evals to -429.0 >= -438 and is True so dec g by -700 to get 469.0
# lpi >= 623 evals to 628.0 >= 623 and is True so dec lpi by 356 to get 272.0
# qn <= 6 evals to 0 <= 6 and is True so inc afu by -227 to get -227.0
# jq != 883 evals to 880.0 != 883 and is True so dec m by 329 to get -329.0
# sh != 2 evals to 0 != 2 and is True so dec qrc by 683 to get -683.0
# qdq <= -7 evals to 0 <= -7 and is False so dec sh by -322 to get 0
# qdq >= 7 evals to 0 >= 7 and is False so inc fkp by 112 to get 0
# wfk >= -1 evals to 0 >= -1 and is True so dec bfx by -258 to get 258.0
# ev >= -1 evals to 0 >= -1 and is True so inc nkr by -259 to get 415.0
# ghj == 693 evals to 693.0 == 693 and is True so dec pr by -806 to get -793.0
# nkr >= 412 evals to 415.0 >= 412 and is True so inc w by -717 to get -690.0
# w < -686 evals to -690.0 < -686 and is True so inc rlq by -755 to get -465.0
# yo <= 2 evals to 0 <= 2 and is True so inc afu by 514 to get 287.0
# bfx <= 252 evals to 258.0 <= 252 and is False so inc a by 697 to get 0
# lpi > 278 evals to 272.0 > 278 and is False so dec qrc by -733 to get -683.0
# ghj != 692 evals to 693.0 != 692 and is True so inc jq by 843 to get 1723.0
# u <= 3 evals to 0 <= 3 and is True so inc jh by -321 to get -321.0
# afu == 287 evals to 287.0 == 287 and is True so dec afu by -86 to get 373.0
# w >= -694 evals to -690.0 >= -694 and is True so inc g by -374 to get 95.0
# k < 565 evals to 567.0 < 565 and is False so inc m by 681 to get -329.0
# u == 0 evals to 0 == 0 and is True so inc ev by -75 to get -75.0
# lpi < 277 evals to 272.0 < 277 and is True so dec w by 130 to get -820.0
# vh == -429 evals to -429.0 == -429 and is True so dec ev by 139 to get -214.0
# m >= -332 evals to -329.0 >= -332 and is True so inc m by -283 to get -612.0
# yo != -2 evals to 0 != -2 and is True so dec fkp by -48 to get 48.0
# t > -747 evals to -737.0 > -747 and is True so dec g by -272 to get 367.0
# pr < -800 evals to -793.0 < -800 and is False so dec wfk by 752 to get 0
# rlq != -467 evals to -465.0 != -467 and is True so inc bfx by -164 to get 94.0
# k <= 566 evals to 567.0 <= 566 and is False so dec k by -470 to get 567.0
# k < 572 evals to 567.0 < 572 and is True so dec ghj by 221 to get 472.0
# bfx > 93 evals to 94.0 > 93 and is True so dec g by 722 to get -355.0
# qdq >= -7 evals to 0 >= -7 and is True so dec wfk by -256 to get 256.0
# bfx > 99 evals to 94.0 > 99 and is False so inc t by 337 to get -737.0
# fkp != 48 evals to 48.0 != 48 and is False so inc w by 134 to get -820.0
# w <= -815 evals to -820.0 <= -815 and is True so inc nkr by -605 to get -190.0
# vh >= -438 evals to -429.0 >= -438 and is True so dec wfk by -938 to get 1194.0
# wfk < 1204 evals to 1194.0 < 1204 and is True so dec pr by -938 to get 145.0
# rlq <= -459 evals to -465.0 <= -459 and is True so inc qn by -372 to get -372.0
# g <= -348 evals to -355.0 <= -348 and is True so dec bfx by -38 to get 132.0
# fkp != 49 evals to 48.0 != 49 and is True so inc qn by 561 to get 189.0
# rlq >= -466 evals to -465.0 >= -466 and is True so dec ghj by 555 to get -83.0
# yo == 0 evals to 0 == 0 and is True so dec qdq by 78 to get -78.0
# vh > -433 evals to -429.0 > -433 and is True so inc ev by -466 to get -680.0
# qdq >= -84 evals to -78.0 >= -84 and is True so inc w by -946 to get -1766.0
# ghj < -74 evals to -83.0 < -74 and is True so inc w by 735 to get -1031.0
# afu == 380 evals to 373.0 == 380 and is False so dec lpi by -616 to get 272.0
# qrc != -678 evals to -683.0 != -678 and is True so dec nkr by 259 to get -449.0
# m < -620 evals to -612.0 < -620 and is False so dec sh by -406 to get 0
# m == -612 evals to -612.0 == -612 and is True so dec jq by -449 to get 2172.0
# qrc > -691 evals to -683.0 > -691 and is True so dec ev by 990 to get -1670.0
# jh > -315 evals to -321.0 > -315 and is False so dec g by -139 to get -355.0
# vh <= -424 evals to -429.0 <= -424 and is True so inc w by 204 to get -827.0
# jq == 2181 evals to 2172.0 == 2181 and is False so dec yo by -26 to get 0
# qrc != -688 evals to -683.0 != -688 and is True so dec a by -528 to get 528.0
# bfx > 128 evals to 132.0 > 128 and is True so inc nkr by -926 to get -1375.0
# w <= -822 evals to -827.0 <= -822 and is True so inc qdq by -241 to get -319.0
# wfk == 1194 evals to 1194.0 == 1194 and is True so inc g by -111 to get -466.0
# qn < 199 evals to 189.0 < 199 and is True so inc bfx by 282 to get 414.0
# wfk == 1194 evals to 1194.0 == 1194 and is True so inc jq by 413 to get 2585.0
# ev < -1660 evals to -1670.0 < -1660 and is True so dec fkp by -281 to get 329.0
# qn != 199 evals to 189.0 != 199 and is True so inc qrc by -596 to get -1279.0
# ghj != -74 evals to -83.0 != -74 and is True so inc ev by 383 to get -1287.0
# yo <= -6 evals to 0 <= -6 and is False so inc sh by -562 to get 0
# wfk <= 1196 evals to 1194.0 <= 1196 and is True so inc sh by 728 to get 728.0
# vh < -423 evals to -429.0 < -423 and is True so dec bfx by -360 to get 774.0
# qn >= 195 evals to 189.0 >= 195 and is False so inc jq by -774 to get 2585.0
# ghj == -87 evals to -83.0 == -87 and is False so dec qn by -939 to get 189.0
# ghj == -83 evals to -83.0 == -83 and is True so dec w by 952 to get -1779.0
# lpi < 278 evals to 272.0 < 278 and is True so dec yo by -112 to get 112.0
# sh == 728 evals to 728.0 == 728 and is True so dec qn by 902 to get -713.0
# qrc == -1279 evals to -1279.0 == -1279 and is True so dec k by 507 to get 60.0
# a != 537 evals to 528.0 != 537 and is True so dec g by 155 to get -621.0
# a < 530 evals to 528.0 < 530 and is True so inc rlq by 655 to get 190.0
# afu == 373 evals to 373.0 == 373 and is True so inc qrc by 523 to get -756.0
# jh != -319 evals to -321.0 != -319 and is True so dec t by 36 to get -773.0
# m > -610 evals to -612.0 > -610 and is False so dec qn by -584 to get -713.0
# sh <= 730 evals to 728.0 <= 730 and is True so inc ev by 406 to get -881.0
# lpi > 277 evals to 272.0 > 277 and is False so dec pr by 699 to get 145.0
# k == 60 evals to 60.0 == 60 and is True so dec a by 906 to get -378.0
# m != -615 evals to -612.0 != -615 and is True so dec jq by -811 to get 3396.0
# qn <= -712 evals to -713.0 <= -712 and is True so inc vh by -874 to get -1303.0
# vh != -1293 evals to -1303.0 != -1293 and is True so inc pr by 325 to get 470.0
# m < -607 evals to -612.0 < -607 and is True so inc nkr by -786 to get -2161.0
# jq != 3389 evals to 3396.0 != 3389 and is True so inc pr by -903 to get -433.0
# rlq <= 182 evals to 190.0 <= 182 and is False so inc fkp by 758 to get 329.0
# sh > 725 evals to 728.0 > 725 and is True so inc lpi by -307 to get -35.0
# jh <= -314 evals to -321.0 <= -314 and is True so inc afu by -162 to get 211.0
# k < 63 evals to 60.0 < 63 and is True so inc afu by -96 to get 115.0
# pr <= -427 evals to -433.0 <= -427 and is True so dec t by 939 to get -1712.0
# a <= -370 evals to -378.0 <= -370 and is True so dec fkp by -65 to get 394.0
# nkr > -2160 evals to -2161.0 > -2160 and is False so dec g by 246 to get -621.0
# sh != 727 evals to 728.0 != 727 and is True so inc w by 62 to get -1717.0
# ev > -891 evals to -881.0 > -891 and is True so dec jh by -621 to get 300.0
# ev != -878 evals to -881.0 != -878 and is True so dec wfk by -84 to get 1278.0
# sh > 725 evals to 728.0 > 725 and is True so inc qdq by 245 to get -74.0
# jh < 310 evals to 300.0 < 310 and is True so dec qdq by 689 to get -763.0
# ghj < -79 evals to -83.0 < -79 and is True so inc sh by -396 to get 332.0
# pr < -429 evals to -433.0 < -429 and is True so dec yo by 457 to get -345.0
# pr > -434 evals to -433.0 > -434 and is True so dec vh by -545 to get -758.0
# nkr > -2166 evals to -2161.0 > -2166 and is True so inc rlq by -848 to get -658.0
# fkp < 401 evals to 394.0 < 401 and is True so inc nkr by 274 to get -1887.0
# fkp > 393 evals to 394.0 > 393 and is True so inc nkr by -165 to get -2052.0
# t <= -1706 evals to -1712.0 <= -1706 and is True so dec u by 973 to get -973.0
# wfk < 1286 evals to 1278.0 < 1286 and is True so dec vh by -874 to get 116.0
# lpi == -35 evals to -35.0 == -35 and is True so inc ghj by 872 to get 789.0
# t == -1712 evals to -1712.0 == -1712 and is True so dec vh by 476 to get -360.0
# nkr > -2062 evals to -2052.0 > -2062 and is True so inc lpi by -780 to get -815.0
# sh != 332 evals to 332.0 != 332 and is False so inc a by 312 to get -378.0
# a == -378 evals to -378.0 == -378 and is True so dec qdq by -840 to get 77.0
# qn <= -707 evals to -713.0 <= -707 and is True so dec k by 287 to get -227.0
# jh != 304 evals to 300.0 != 304 and is True so dec rlq by 250 to get -908.0
# qrc == -756 evals to -756.0 == -756 and is True so dec qdq by -870 to get 947.0
# qrc < -750 evals to -756.0 < -750 and is True so dec pr by 95 to get -528.0
# jq <= 3400 evals to 3396.0 <= 3400 and is True so dec m by 21 to get -633.0
# vh == -360 evals to -360.0 == -360 and is True so dec qrc by -995 to get 239.0
# g > -626 evals to -621.0 > -626 and is True so inc fkp by 422 to get 816.0
# rlq == -908 evals to -908.0 == -908 and is True so inc rlq by 744 to get -164.0
# rlq >= -168 evals to -164.0 >= -168 and is True so dec qdq by -856 to get 1803.0
# rlq <= -164 evals to -164.0 <= -164 and is True so inc wfk by -53 to get 1225.0
# a == -378 evals to -378.0 == -378 and is True so dec bfx by 370 to get 404.0
# lpi <= -812 evals to -815.0 <= -812 and is True so dec w by 388 to get -2105.0
# a <= -375 evals to -378.0 <= -375 and is True so inc jh by -458 to get -158.0
# m < -623 evals to -633.0 < -623 and is True so dec ev by 169 to get -1050.0
# afu <= 117 evals to 115.0 <= 117 and is True so dec afu by 673 to get -558.0
# vh >= -362 evals to -360.0 >= -362 and is True so dec jq by -294 to get 3690.0
# qn >= -711 evals to -713.0 >= -711 and is False so inc ghj by -595 to get 789.0
# lpi <= -823 evals to -815.0 <= -823 and is False so inc m by -292 to get -633.0
# pr >= -536 evals to -528.0 >= -536 and is True so inc wfk by -401 to get 824.0
# fkp <= 818 evals to 816.0 <= 818 and is True so inc w by -846 to get -2951.0
# fkp <= 825 evals to 816.0 <= 825 and is True so inc afu by 224 to get -334.0
# fkp != 816 evals to 816.0 != 816 and is False so dec qdq by -22 to get 1803.0
# qn == -713 evals to -713.0 == -713 and is True so inc bfx by 148 to get 552.0
# lpi >= -815 evals to -815.0 >= -815 and is True so inc qrc by -253 to get -14.0
# fkp != 816 evals to 816.0 != 816 and is False so inc w by -824 to get -2951.0
# wfk <= 821 evals to 824.0 <= 821 and is False so inc jq by 409 to get 3690.0
# ev < -1044 evals to -1050.0 < -1044 and is True so inc a by -243 to get -621.0
# afu <= -329 evals to -334.0 <= -329 and is True so inc ev by 784 to get -266.0
# a > -625 evals to -621.0 > -625 and is True so inc a by 492 to get -129.0
# afu != -327 evals to -334.0 != -327 and is True so dec qrc by 675 to get -689.0
# g > -623 evals to -621.0 > -623 and is True so inc yo by -902 to get -1247.0
# m <= -632 evals to -633.0 <= -632 and is True so inc jh by -341 to get -499.0
# g > -622 evals to -621.0 > -622 and is True so inc rlq by 139 to get -25.0
# vh <= -355 evals to -360.0 <= -355 and is True so inc qdq by -156 to get 1647.0
# qdq > 1646 evals to 1647.0 > 1646 and is True so inc ev by 105 to get -161.0
# u < -981 evals to -973.0 < -981 and is False so dec g by -334 to get -621.0
# lpi < -810 evals to -815.0 < -810 and is True so inc qn by -117 to get -830.0
# jq > 3687 evals to 3690.0 > 3687 and is True so dec fkp by -419 to get 1235.0
# wfk <= 830 evals to 824.0 <= 830 and is True so inc lpi by 950 to get 135.0
# k <= -224 evals to -227.0 <= -224 and is True so inc m by 305 to get -328.0
# vh != -365 evals to -360.0 != -365 and is True so inc yo by -355 to get -1602.0
# t < -1710 evals to -1712.0 < -1710 and is True so dec jh by 775 to get -1274.0
# nkr > -2054 evals to -2052.0 > -2054 and is True so dec qrc by 125 to get -814.0
# nkr <= -2049 evals to -2052.0 <= -2049 and is True so inc lpi by 572 to get 707.0
# ghj <= 791 evals to 789.0 <= 791 and is True so dec rlq by 913 to get -938.0
# m >= -330 evals to -328.0 >= -330 and is True so dec g by -25 to get -596.0
# ev == -161 evals to -161.0 == -161 and is True so dec bfx by -973 to get 1525.0
# t >= -1718 evals to -1712.0 >= -1718 and is True so inc sh by -500 to get -168.0
# qn < -820 evals to -830.0 < -820 and is True so inc afu by 496 to get 162.0
# vh >= -365 evals to -360.0 >= -365 and is True so inc afu by 242 to get 404.0
# m == -328 evals to -328.0 == -328 and is True so dec t by -474 to get -1238.0
# g <= -587 evals to -596.0 <= -587 and is True so dec w by -597 to get -2354.0
# jq == 3690 evals to 3690.0 == 3690 and is True so dec qdq by 681 to get 966.0
# bfx != 1530 evals to 1525.0 != 1530 and is True so dec k by -349 to get 122.0
# yo != -1595 evals to -1602.0 != -1595 and is True so inc pr by -430 to get -958.0
# afu != 410 evals to 404.0 != 410 and is True so inc nkr by 105 to get -1947.0
# jh < -1272 evals to -1274.0 < -1272 and is True so dec w by -788 to get -1566.0
# ghj >= 785 evals to 789.0 >= 785 and is True so inc lpi by 328 to get 1035.0
# vh <= -368 evals to -360.0 <= -368 and is False so inc rlq by 694 to get -938.0
# ev != -168 evals to -161.0 != -168 and is True so inc a by 965 to get 836.0
# jq < 3690 evals to 3690.0 < 3690 and is False so inc g by -962 to get -596.0
# lpi == 1035 evals to 1035.0 == 1035 and is True so inc pr by -181 to get -1139.0
# rlq >= -947 evals to -938.0 >= -947 and is True so dec rlq by 509 to get -1447.0
# w >= -1573 evals to -1566.0 >= -1573 and is True so dec k by -991 to get 1113.0
# qrc < -816 evals to -814.0 < -816 and is False so dec bfx by -516 to get 1525.0
# qdq == 961 evals to 966.0 == 961 and is False so dec a by 679 to get 836.0
# jh <= -1273 evals to -1274.0 <= -1273 and is True so inc lpi by -640 to get 395.0
# rlq >= -1440 evals to -1447.0 >= -1440 and is False so dec w by -13 to get -1566.0
# lpi > 402 evals to 395.0 > 402 and is False so dec m by 535 to get -328.0
# t > -1241 evals to -1238.0 > -1241 and is True so dec sh by -358 to get 190.0
# wfk > 821 evals to 824.0 > 821 and is True so inc qdq by -647 to get 319.0
# a < 838 evals to 836.0 < 838 and is True so dec u by 409 to get -1382.0
# wfk < 832 evals to 824.0 < 832 and is True so dec lpi by 745 to get -350.0
# w < -1564 evals to -1566.0 < -1564 and is True so dec yo by 422 to get -2024.0
# m > -319 evals to -328.0 > -319 and is False so dec jq by 555 to get 3690.0
# qrc < -805 evals to -814.0 < -805 and is True so inc fkp by 202 to get 1437.0
# vh == -355 evals to -360.0 == -355 and is False so dec wfk by -52 to get 824.0
# jq < 3699 evals to 3690.0 < 3699 and is True so inc pr by 473 to get -666.0
# pr > -674 evals to -666.0 > -674 and is True so dec bfx by -202 to get 1727.0
# ghj <= 787 evals to 789.0 <= 787 and is False so inc fkp by 907 to get 1437.0
# rlq > -1455 evals to -1447.0 > -1455 and is True so inc yo by -617 to get -2641.0
# jq != 3699 evals to 3690.0 != 3699 and is True so inc jq by -300 to get 3390.0
# nkr < -1945 evals to -1947.0 < -1945 and is True so dec u by 910 to get -2292.0
# bfx < 1722 evals to 1727.0 < 1722 and is False so dec g by -880 to get -596.0
# ev > -166 evals to -161.0 > -166 and is True so inc ev by 47 to get -114.0
# afu == 404 evals to 404.0 == 404 and is True so inc a by 372 to get 1208.0
# qdq != 319 evals to 319.0 != 319 and is False so inc u by 318 to get -2292.0
# qdq == 319 evals to 319.0 == 319 and is True so inc afu by 942 to get 1346.0
# ghj <= 793 evals to 789.0 <= 793 and is True so dec sh by 522 to get -332.0
# g <= -588 evals to -596.0 <= -588 and is True so dec m by -785 to get 457.0
# qrc <= -805 evals to -814.0 <= -805 and is True so dec pr by 878 to get -1544.0
# m != 452 evals to 457.0 != 452 and is True so inc a by -812 to get 396.0
# lpi >= -355 evals to -350.0 >= -355 and is True so dec wfk by -695 to get 1519.0
# jh >= -1279 evals to -1274.0 >= -1279 and is True so dec qdq by -493 to get 812.0
# k < 1115 evals to 1113.0 < 1115 and is True so dec pr by 325 to get -1869.0
# sh >= -333 evals to -332.0 >= -333 and is True so inc nkr by 581 to get -1366.0
# pr == -1861 evals to -1869.0 == -1861 and is False so dec a by -368 to get 396.0
# qn >= -835 evals to -830.0 >= -835 and is True so dec ghj by 135 to get 654.0
# a < 406 evals to 396.0 < 406 and is True so dec jh by -209 to get -1065.0
# lpi > -352 evals to -350.0 > -352 and is True so dec u by -518 to get -1774.0
# t > -1239 evals to -1238.0 > -1239 and is True so inc qdq by 598 to get 1410.0
# m != 459 evals to 457.0 != 459 and is True so dec k by -879 to get 1992.0
# nkr == -1366 evals to -1366.0 == -1366 and is True so dec fkp by -587 to get 2024.0
# qrc <= -806 evals to -814.0 <= -806 and is True so dec yo by -902 to get -1739.0
# yo == -1739 evals to -1739.0 == -1739 and is True so dec nkr by -948 to get -418.0
# k != 1998 evals to 1992.0 != 1998 and is True so inc pr by -317 to get -2186.0
# bfx == 1722 evals to 1727.0 == 1722 and is False so inc ghj by 535 to get 654.0
# vh == -360 evals to -360.0 == -360 and is True so inc nkr by -72 to get -490.0
# rlq != -1455 evals to -1447.0 != -1455 and is True so dec ev by -234 to get 120.0
# k == 1992 evals to 1992.0 == 1992 and is True so dec a by 869 to get -473.0
# yo >= -1746 evals to -1739.0 >= -1746 and is True so inc ev by -397 to get -277.0
# bfx <= 1734 evals to 1727.0 <= 1734 and is True so dec bfx by 642 to get 1085.0
# jh <= -1057 evals to -1065.0 <= -1057 and is True so dec jq by 501 to get 2889.0
# qdq == 1410 evals to 1410.0 == 1410 and is True so inc w by 900 to get -666.0
# ev >= -277 evals to -277.0 >= -277 and is True so dec lpi by 742 to get -1092.0
# rlq != -1441 evals to -1447.0 != -1441 and is True so dec pr by 842 to get -3028.0
# a == -473 evals to -473.0 == -473 and is True so inc qdq by -56 to get 1354.0
# a != -470 evals to -473.0 != -470 and is True so dec jh by -421 to get -644.0
# k >= 1997 evals to 1992.0 >= 1997 and is False so inc jq by 60 to get 2889.0
# g <= -592 evals to -596.0 <= -592 and is True so inc lpi by 181 to get -911.0
# afu < 1349 evals to 1346.0 < 1349 and is True so inc jh by -888 to get -1532.0
# lpi >= -912 evals to -911.0 >= -912 and is True so inc w by 271 to get -395.0
# jq <= 2890 evals to 2889.0 <= 2890 and is True so dec wfk by 319 to get 1200.0
# vh >= -368 evals to -360.0 >= -368 and is True so inc qrc by 144 to get -670.0
# nkr <= -492 evals to -490.0 <= -492 and is False so dec rlq by 263 to get -1447.0
# wfk <= 1208 evals to 1200.0 <= 1208 and is True so inc sh by 214 to get -118.0
# qrc < -673 evals to -670.0 < -673 and is False so inc k by -39 to get 1992.0
# qn == -830 evals to -830.0 == -830 and is True so dec rlq by -388 to get -1059.0
# vh > -366 evals to -360.0 > -366 and is True so inc fkp by 917 to get 2941.0
# qrc < -663 evals to -670.0 < -663 and is True so dec u by -225 to get -1549.0
# u > -1550 evals to -1549.0 > -1550 and is True so dec lpi by -741 to get -170.0
# afu <= 1354 evals to 1346.0 <= 1354 and is True so inc lpi by -176 to get -346.0
# k <= 1995 evals to 1992.0 <= 1995 and is True so inc u by 454 to get -1095.0
# rlq >= -1059 evals to -1059.0 >= -1059 and is True so inc qn by 623 to get -207.0
# nkr < -485 evals to -490.0 < -485 and is True so inc fkp by 642 to get 3583.0
# pr < -3027 evals to -3028.0 < -3027 and is True so dec jh by 895 to get -2427.0
# fkp < 3592 evals to 3583.0 < 3592 and is True so dec k by 240 to get 1752.0
# vh < -367 evals to -360.0 < -367 and is False so dec afu by 772 to get 1346.0
# a < -467 evals to -473.0 < -467 and is True so dec nkr by 913 to get -1403.0
# lpi != -336 evals to -346.0 != -336 and is True so inc vh by -941 to get -1301.0
# nkr != -1409 evals to -1403.0 != -1409 and is True so inc pr by -623 to get -3651.0
# qdq != 1356 evals to 1354.0 != 1356 and is True so dec g by 849 to get -1445.0
# t >= -1240 evals to -1238.0 >= -1240 and is True so dec bfx by -647 to get 1732.0
# w != -398 evals to -395.0 != -398 and is True so dec jh by 654 to get -3081.0
# g != -1442 evals to -1445.0 != -1442 and is True so inc a by -938 to get -1411.0
# yo > -1747 evals to -1739.0 > -1747 and is True so dec jq by 545 to get 2344.0
# vh >= -1301 evals to -1301.0 >= -1301 and is True so dec qdq by 183 to get 1171.0
# qn != -212 evals to -207.0 != -212 and is True so inc fkp by -628 to get 2955.0
# qdq == 1171 evals to 1171.0 == 1171 and is True so dec u by -89 to get -1006.0
# m > 448 evals to 457.0 > 448 and is True so inc qrc by -623 to get -1293.0
# t < -1237 evals to -1238.0 < -1237 and is True so inc pr by 61 to get -3590.0
# qn < -204 evals to -207.0 < -204 and is True so dec u by 83 to get -1089.0
# m <= 466 evals to 457.0 <= 466 and is True so inc qrc by 179 to get -1114.0
# nkr != -1408 evals to -1403.0 != -1408 and is True so dec nkr by 2 to get -1405.0
# u >= -1094 evals to -1089.0 >= -1094 and is True so dec fkp by 813 to get 2142.0
# sh < -111 evals to -118.0 < -111 and is True so dec sh by -127 to get 9.0
# rlq <= -1069 evals to -1059.0 <= -1069 and is False so dec qdq by 697 to get 1171.0
# k == 1752 evals to 1752.0 == 1752 and is True so dec t by 191 to get -1429.0
# bfx != 1725 evals to 1732.0 != 1725 and is True so dec u by 352 to get -1441.0
# fkp == 2145 evals to 2142.0 == 2145 and is False so inc nkr by 188 to get -1405.0
# wfk >= 1192 evals to 1200.0 >= 1192 and is True so inc qn by -300 to get -507.0
# jq >= 2345 evals to 2344.0 >= 2345 and is False so dec nkr by -520 to get -1405.0
# g < -1446 evals to -1445.0 < -1446 and is False so dec pr by 957 to get -3590.0
# g <= -1436 evals to -1445.0 <= -1436 and is True so inc g by -2 to get -1447.0
# vh <= -1307 evals to -1301.0 <= -1307 and is False so dec w by -64 to get -395.0
# w < -387 evals to -395.0 < -387 and is True so inc qn by 290 to get -217.0
# bfx > 1726 evals to 1732.0 > 1726 and is True so dec yo by -511 to get -1228.0
# bfx < 1742 evals to 1732.0 < 1742 and is True so inc qrc by -534 to get -1648.0
# qn == -226 evals to -217.0 == -226 and is False so dec fkp by 456 to get 2142.0
# pr > -3597 evals to -3590.0 > -3597 and is True so dec ev by 409 to get -686.0
# lpi > -348 evals to -346.0 > -348 and is True so dec k by 457 to get 1295.0
# bfx > 1728 evals to 1732.0 > 1728 and is True so inc t by -705 to get -2134.0
# u >= -1450 evals to -1441.0 >= -1450 and is True so dec a by 935 to get -2346.0
# vh > -1309 evals to -1301.0 > -1309 and is True so inc a by -904 to get -3250.0
# u < -1434 evals to -1441.0 < -1434 and is True so inc ev by 873 to get 187.0
# k != 1286 evals to 1295.0 != 1286 and is True so inc m by 704 to get 1161.0
# qn > -213 evals to -217.0 > -213 and is False so inc m by -331 to get 1161.0
# m <= 1161 evals to 1161.0 <= 1161 and is True so inc t by -5 to get -2139.0
# rlq >= -1066 evals to -1059.0 >= -1066 and is True so dec yo by 153 to get -1381.0
# u <= -1436 evals to -1441.0 <= -1436 and is True so dec qn by -693 to get 476.0
# g > -1451 evals to -1447.0 > -1451 and is True so dec w by -812 to get 417.0
# ev > 180 evals to 187.0 > 180 and is True so inc ghj by -838 to get -184.0
# jh <= -3077 evals to -3081.0 <= -3077 and is True so inc vh by -462 to get -1763.0
# bfx <= 1738 evals to 1732.0 <= 1738 and is True so inc rlq by 806 to get -253.0
# yo >= -1387 evals to -1381.0 >= -1387 and is True so dec nkr by 827 to get -2232.0
# m > 1154 evals to 1161.0 > 1154 and is True so inc sh by -200 to get -191.0
# t == -2147 evals to -2139.0 == -2147 and is False so inc m by 397 to get 1161.0
# qrc == -1648 evals to -1648.0 == -1648 and is True so dec qdq by -345 to get 1516.0
# afu > 1337 evals to 1346.0 > 1337 and is True so inc ev by -238 to get -51.0
# u >= -1448 evals to -1441.0 >= -1448 and is True so dec ev by -284 to get 233.0
# afu == 1346 evals to 1346.0 == 1346 and is True so dec g by 108 to get -1555.0
# ev != 230 evals to 233.0 != 230 and is True so inc ghj by 291 to get 107.0
# rlq == -253 evals to -253.0 == -253 and is True so inc jh by -367 to get -3448.0
# m != 1164 evals to 1161.0 != 1164 and is True so inc u by -88 to get -1529.0
# m >= 1160 evals to 1161.0 >= 1160 and is True so inc qrc by -513 to get -2161.0
# bfx == 1734 evals to 1732.0 == 1734 and is False so inc m by 428 to get 1161.0
# w <= 421 evals to 417.0 <= 421 and is True so inc wfk by -566 to get 634.0
# w < 426 evals to 417.0 < 426 and is True so dec nkr by 795 to get -3027.0
# sh <= -189 evals to -191.0 <= -189 and is True so dec k by -372 to get 1667.0
# t < -2137 evals to -2139.0 < -2137 and is True so inc lpi by -167 to get -513.0
# qdq != 1522 evals to 1516.0 != 1522 and is True so dec rlq by -939 to get 686.0
# jh < -3439 evals to -3448.0 < -3439 and is True so dec yo by 223 to get -1604.0
# ghj < 108 evals to 107.0 < 108 and is True so dec qrc by -151 to get -2010.0
# ev > 229 evals to 233.0 > 229 and is True so inc fkp by 172 to get 2314.0
# u == -1529 evals to -1529.0 == -1529 and is True so inc qdq by -527 to get 989.0
# vh == -1763 evals to -1763.0 == -1763 and is True so dec u by -376 to get -1153.0
# u <= -1149 evals to -1153.0 <= -1149 and is True so inc nkr by 201 to get -2826.0
# pr != -3595 evals to -3590.0 != -3595 and is True so dec qdq by -277 to get 1266.0
# qdq > 1256 evals to 1266.0 > 1256 and is True so dec ghj by 560 to get -453.0
# jh <= -3444 evals to -3448.0 <= -3444 and is True so inc sh by -957 to get -1148.0
# wfk >= 627 evals to 634.0 >= 627 and is True so inc a by 926 to get -2324.0
# yo < -1594 evals to -1604.0 < -1594 and is True so dec pr by -156 to get -3434.0
# t >= -2147 evals to -2139.0 >= -2147 and is True so inc rlq by 942 to get 1628.0
# rlq != 1620 evals to 1628.0 != 1620 and is True so inc qrc by -702 to get -2712.0
# g >= -1550 evals to -1555.0 >= -1550 and is False so inc qdq by -202 to get 1266.0
# fkp < 2320 evals to 2314.0 < 2320 and is True so dec ghj by 939 to get -1392.0
# jq == 2344 evals to 2344.0 == 2344 and is True so dec qdq by -990 to get 2256.0
# qdq != 2262 evals to 2256.0 != 2262 and is True so inc vh by -584 to get -2347.0
# wfk >= 631 evals to 634.0 >= 631 and is True so dec ev by 893 to get -660.0
# jh <= -3444 evals to -3448.0 <= -3444 and is True so inc pr by 441 to get -2993.0
# fkp >= 2309 evals to 2314.0 >= 2309 and is True so inc m by 262 to get 1423.0
# g == -1555 evals to -1555.0 == -1555 and is True so inc k by 784 to get 2451.0
# lpi >= -520 evals to -513.0 >= -520 and is True so dec jq by 425 to get 1919.0
# qn == 481 evals to 476.0 == 481 and is False so dec pr by 703 to get -2993.0
# yo < -1612 evals to -1604.0 < -1612 and is False so dec afu by 380 to get 1346.0
# sh == -1148 evals to -1148.0 == -1148 and is True so dec qrc by 919 to get -3631.0
# jh != -3456 evals to -3448.0 != -3456 and is True so inc qdq by 148 to get 2404.0
# m >= 1425 evals to 1423.0 >= 1425 and is False so inc k by -203 to get 2451.0
# qdq >= 2403 evals to 2404.0 >= 2403 and is True so dec sh by -5 to get -1143.0
# pr < -2992 evals to -2993.0 < -2992 and is True so dec w by -310 to get 727.0
# nkr > -2827 evals to -2826.0 > -2827 and is True so inc u by -631 to get -1784.0
# u <= -1789 evals to -1784.0 <= -1789 and is False so dec fkp by 858 to get 2314.0
# wfk != 636 evals to 634.0 != 636 and is True so dec ev by 351 to get -1011.0
# ghj >= -1400 evals to -1392.0 >= -1400 and is True so inc sh by 875 to get -268.0
# qn == 476 evals to 476.0 == 476 and is True so inc qn by 206 to get 682.0
# pr >= -2988 evals to -2993.0 >= -2988 and is False so inc pr by -973 to get -2993.0
# a < -2315 evals to -2324.0 < -2315 and is True so inc qrc by 267 to get -3364.0
# lpi != -519 evals to -513.0 != -519 and is True so inc k by -176 to get 2275.0
# sh <= -267 evals to -268.0 <= -267 and is True so dec g by -388 to get -1167.0
# lpi >= -516 evals to -513.0 >= -516 and is True so dec ghj by 706 to get -2098.0
# rlq == 1628 evals to 1628.0 == 1628 and is True so dec sh by -616 to get 348.0
# g < -1157 evals to -1167.0 < -1157 and is True so dec fkp by 199 to get 2115.0
# qn > 687 evals to 682.0 > 687 and is False so dec qn by 749 to get 682.0
# wfk == 634 evals to 634.0 == 634 and is True so inc qn by -250 to get 432.0
# qdq > 2398 evals to 2404.0 > 2398 and is True so dec m by 4 to get 1419.0
# ev >= -1015 evals to -1011.0 >= -1015 and is True so inc t by 723 to get -1416.0
# ev < -1006 evals to -1011.0 < -1006 and is True so dec w by 377 to get 350.0
# sh > 340 evals to 348.0 > 340 and is True so inc qdq by 662 to get 3066.0
# ev < -1011 evals to -1011.0 < -1011 and is False so inc yo by 944 to get -1604.0
# bfx >= 1732 evals to 1732.0 >= 1732 and is True so inc nkr by 625 to get -2201.0
# vh < -2350 evals to -2347.0 < -2350 and is False so inc bfx by 313 to get 1732.0
# ghj != -2098 evals to -2098.0 != -2098 and is False so inc u by -675 to get -1784.0
# vh >= -2349 evals to -2347.0 >= -2349 and is True so dec bfx by -228 to get 1960.0
# ev > -1006 evals to -1011.0 > -1006 and is False so inc lpi by -269 to get -513.0
# ghj < -2091 evals to -2098.0 < -2091 and is True so dec qn by -264 to get 696.0
# vh == -2347 evals to -2347.0 == -2347 and is True so inc yo by -718 to get -2322.0
# k < 2276 evals to 2275.0 < 2276 and is True so dec ghj by -646 to get -1452.0
# u != -1793 evals to -1784.0 != -1793 and is True so inc m by -541 to get 878.0
# jh >= -3456 evals to -3448.0 >= -3456 and is True so inc w by 809 to get 1159.0
# jq <= 1912 evals to 1919.0 <= 1912 and is False so dec qrc by 962 to get -3364.0
# lpi > -514 evals to -513.0 > -514 and is True so dec k by -908 to get 3183.0
# m < 884 evals to 878.0 < 884 and is True so dec g by -163 to get -1004.0
# vh < -2338 evals to -2347.0 < -2338 and is True so inc pr by -801 to get -3794.0
# vh < -2341 evals to -2347.0 < -2341 and is True so inc a by 958 to get -1366.0
# vh >= -2347 evals to -2347.0 >= -2347 and is True so inc fkp by 452 to get 2567.0
# k < 3179 evals to 3183.0 < 3179 and is False so dec nkr by -481 to get -2201.0
# u >= -1778 evals to -1784.0 >= -1778 and is False so inc g by 682 to get -1004.0
# bfx >= 1968 evals to 1960.0 >= 1968 and is False so dec vh by -178 to get -2347.0
# qn > 686 evals to 696.0 > 686 and is True so dec qn by -293 to get 989.0
# sh != 352 evals to 348.0 != 352 and is True so dec sh by 612 to get -264.0
# lpi <= -505 evals to -513.0 <= -505 and is True so dec bfx by 473 to get 1487.0
# a != -1376 evals to -1366.0 != -1376 and is True so dec m by 77 to get 801.0
# qn != 987 evals to 989.0 != 987 and is True so dec rlq by 709 to get 919.0
# qdq >= 3068 evals to 3066.0 >= 3068 and is False so inc vh by -342 to get -2347.0
# t <= -1416 evals to -1416.0 <= -1416 and is True so dec lpi by -146 to get -367.0
# nkr >= -2209 evals to -2201.0 >= -2209 and is True so inc vh by 949 to get -1398.0
# rlq < 926 evals to 919.0 < 926 and is True so dec jh by -311 to get -3137.0
# qn > 987 evals to 989.0 > 987 and is True so dec yo by 407 to get -2729.0
# qdq != 3056 evals to 3066.0 != 3056 and is True so inc qrc by -530 to get -3894.0
# pr >= -3802 evals to -3794.0 >= -3802 and is True so inc lpi by -879 to get -1246.0
# qn <= 987 evals to 989.0 <= 987 and is False so dec qrc by -456 to get -3894.0
# pr < -3785 evals to -3794.0 < -3785 and is True so dec t by -656 to get -760.0
# wfk != 629 evals to 634.0 != 629 and is True so dec a by 382 to get -1748.0
# u != -1790 evals to -1784.0 != -1790 and is True so inc pr by -873 to get -4667.0
# wfk >= 628 evals to 634.0 >= 628 and is True so dec ev by -719 to get -292.0
# fkp > 2569 evals to 2567.0 > 2569 and is False so dec qrc by -324 to get -3894.0
# qrc >= -3892 evals to -3894.0 >= -3892 and is False so dec g by -53 to get -1004.0
# ghj < -1446 evals to -1452.0 < -1446 and is True so inc bfx by -869 to get 618.0
# a < -1739 evals to -1748.0 < -1739 and is True so dec ev by 528 to get -820.0
# vh <= -1402 evals to -1398.0 <= -1402 and is False so inc sh by 260 to get -264.0
# afu > 1354 evals to 1346.0 > 1354 and is False so inc yo by -751 to get -2729.0
# pr == -4667 evals to -4667.0 == -4667 and is True so inc afu by -609 to get 737.0
# m >= 798 evals to 801.0 >= 798 and is True so inc wfk by -413 to get 221.0
# lpi <= -1245 evals to -1246.0 <= -1245 and is True so inc u by -701 to get -2485.0
# nkr != -2205 evals to -2201.0 != -2205 and is True so dec ev by -712 to get -108.0
# fkp != 2558 evals to 2567.0 != 2558 and is True so dec sh by 482 to get -746.0
# a >= -1753 evals to -1748.0 >= -1753 and is True so dec nkr by -302 to get -1899.0
# m < 795 evals to 801.0 < 795 and is False so inc k by -354 to get 3183.0
# sh == -746 evals to -746.0 == -746 and is True so inc bfx by 949 to get 1567.0
# u <= -2480 evals to -2485.0 <= -2480 and is True so dec lpi by 407 to get -1653.0
# pr < -4666 evals to -4667.0 < -4666 and is True so dec qn by -759 to get 1748.0
# afu > 733 evals to 737.0 > 733 and is True so dec rlq by 118 to get 801.0
# g == -1004 evals to -1004.0 == -1004 and is True so inc w by -978 to get 181.0
# qrc != -3894 evals to -3894.0 != -3894 and is False so inc sh by -379 to get -746.0
# wfk > 213 evals to 221.0 > 213 and is True so inc a by 331 to get -1417.0
# bfx == 1567 evals to 1567.0 == 1567 and is True so dec wfk by 476 to get -255.0
# qdq > 3073 evals to 3066.0 > 3073 and is False so dec vh by 980 to get -1398.0
# nkr > -1901 evals to -1899.0 > -1901 and is True so inc jq by 596 to get 2515.0
# fkp <= 2573 evals to 2567.0 <= 2573 and is True so inc nkr by 142 to get -1757.0
# sh >= -753 evals to -746.0 >= -753 and is True so inc yo by -343 to get -3072.0
# a != -1427 evals to -1417.0 != -1427 and is True so inc bfx by 422 to get 1989.0
# bfx <= 1994 evals to 1989.0 <= 1994 and is True so dec a by -593 to get -824.0
# qdq <= 3062 evals to 3066.0 <= 3062 and is False so dec ghj by 674 to get -1452.0
# w > 172 evals to 181.0 > 172 and is True so inc ghj by -759 to get -2211.0
# qdq >= 3060 evals to 3066.0 >= 3060 and is True so dec qn by -754 to get 2502.0
# qn <= 2507 evals to 2502.0 <= 2507 and is True so dec qdq by 971 to get 2095.0
# nkr != -1756 evals to -1757.0 != -1756 and is True so inc w by 183 to get 364.0
# jh != -3145 evals to -3137.0 != -3145 and is True so dec vh by 27 to get -1425.0
# t < -758 evals to -760.0 < -758 and is True so inc m by -466 to get 335.0
# u != -2477 evals to -2485.0 != -2477 and is True so inc qdq by 28 to get 2123.0
# qdq >= 2119 evals to 2123.0 >= 2119 and is True so inc nkr by -676 to get -2433.0
# afu >= 731 evals to 737.0 >= 731 and is True so inc jh by -701 to get -3838.0
# nkr < -2432 evals to -2433.0 < -2432 and is True so inc bfx by -995 to get 994.0
# sh == -746 evals to -746.0 == -746 and is True so inc vh by -211 to get -1636.0
# lpi > -1659 evals to -1653.0 > -1659 and is True so dec pr by 896 to get -5563.0
# pr > -5568 evals to -5563.0 > -5568 and is True so dec sh by 259 to get -1005.0
# fkp <= 2566 evals to 2567.0 <= 2566 and is False so dec m by 138 to get 335.0
# qrc <= -3888 evals to -3894.0 <= -3888 and is True so dec g by 420 to get -1424.0
# yo > -3074 evals to -3072.0 > -3074 and is True so inc vh by 840 to get -796.0
# a <= -824 evals to -824.0 <= -824 and is True so dec nkr by 642 to get -3075.0
# w >= 359 evals to 364.0 >= 359 and is True so inc nkr by 524 to get -2551.0
# wfk == -255 evals to -255.0 == -255 and is True so dec ghj by -992 to get -1219.0
# vh == -796 evals to -796.0 == -796 and is True so dec qrc by -75 to get -3819.0
# g < -1423 evals to -1424.0 < -1423 and is True so inc bfx by 1000 to get 1994.0
# a >= -819 evals to -824.0 >= -819 and is False so dec g by -716 to get -1424.0
# sh != -999 evals to -1005.0 != -999 and is True so inc nkr by -806 to get -3357.0
# yo < -3062 evals to -3072.0 < -3062 and is True so inc pr by 83 to get -5480.0
# g != -1424 evals to -1424.0 != -1424 and is False so dec pr by 231 to get -5480.0
# lpi <= -1651 evals to -1653.0 <= -1651 and is True so inc vh by 99 to get -697.0
# t <= -759 evals to -760.0 <= -759 and is True so inc u by -294 to get -2779.0
# wfk < -245 evals to -255.0 < -245 and is True so inc fkp by -163 to get 2404.0
# afu == 727 evals to 737.0 == 727 and is False so inc k by -221 to get 3183.0
# qn == 2502 evals to 2502.0 == 2502 and is True so dec w by -661 to get 1025.0
# nkr > -3364 evals to -3357.0 > -3364 and is True so inc ev by -892 to get -1000.0
# g != -1434 evals to -1424.0 != -1434 and is True so inc fkp by -224 to get 2180.0
# t > -752 evals to -760.0 > -752 and is False so inc fkp by -517 to get 2180.0
# qrc != -3811 evals to -3819.0 != -3811 and is True so dec sh by 268 to get -1273.0
# bfx == 1994 evals to 1994.0 == 1994 and is True so inc sh by 907 to get -366.0
# afu > 728 evals to 737.0 > 728 and is True so inc sh by -441 to get -807.0
# fkp == 2176 evals to 2180.0 == 2176 and is False so inc yo by 81 to get -3072.0
# ghj >= -1227 evals to -1219.0 >= -1227 and is True so inc lpi by -280 to get -1933.0
# ev > -1000 evals to -1000.0 > -1000 and is False so inc qdq by -133 to get 2123.0
# fkp == 2180 evals to 2180.0 == 2180 and is True so dec afu by -91 to get 828.0
# k <= 3191 evals to 3183.0 <= 3191 and is True so inc qn by 513 to get 3015.0
# bfx == 1994 evals to 1994.0 == 1994 and is True so dec u by -441 to get -2338.0
# qdq > 2113 evals to 2123.0 > 2113 and is True so dec m by 294 to get 41.0
# ev > -1004 evals to -1000.0 > -1004 and is True so inc w by 43 to get 1068.0
# ev > -998 evals to -1000.0 > -998 and is False so inc w by 742 to get 1068.0
# rlq > 801 evals to 801.0 > 801 and is False so inc ev by -574 to get -1000.0
# qdq <= 2127 evals to 2123.0 <= 2127 and is True so dec wfk by 811 to get -1066.0
# nkr <= -3349 evals to -3357.0 <= -3349 and is True so dec bfx by -710 to get 2704.0
# lpi < -1933 evals to -1933.0 < -1933 and is False so inc jh by -249 to get -3838.0
# jq >= 2506 evals to 2515.0 >= 2506 and is True so inc jh by 471 to get -3367.0
# qdq > 2118 evals to 2123.0 > 2118 and is True so inc ev by 172 to get -828.0
# qrc >= -3811 evals to -3819.0 >= -3811 and is False so dec m by 7 to get 41.0
# afu > 823 evals to 828.0 > 823 and is True so inc u by 409 to get -1929.0
# qrc < -3820 evals to -3819.0 < -3820 and is False so dec qn by 320 to get 3015.0
# g == -1424 evals to -1424.0 == -1424 and is True so inc vh by 861 to get 164.0
# ev > -830 evals to -828.0 > -830 and is True so inc pr by 303 to get -5177.0
# sh < -810 evals to -807.0 < -810 and is False so inc vh by 939 to get 164.0
# a >= -815 evals to -824.0 >= -815 and is False so dec a by 903 to get -824.0
# sh != -815 evals to -807.0 != -815 and is True so inc jq by 933 to get 3448.0
# k != 3188 evals to 3183.0 != 3188 and is True so inc qn by 614 to get 3629.0
# jh == -3367 evals to -3367.0 == -3367 and is True so dec ev by 864 to get -1692.0
# rlq == 801 evals to 801.0 == 801 and is True so dec jh by -590 to get -2777.0
# u != -1924 evals to -1929.0 != -1924 and is True so dec yo by 115 to get -3187.0
# m == 41 evals to 41.0 == 41 and is True so dec wfk by 254 to get -1320.0
# fkp >= 2171 evals to 2180.0 >= 2171 and is True so dec sh by 259 to get -1066.0
# bfx <= 2704 evals to 2704.0 <= 2704 and is True so inc ghj by 571 to get -648.0
# g == -1424 evals to -1424.0 == -1424 and is True so dec ghj by 128 to get -776.0
# bfx != 2704 evals to 2704.0 != 2704 and is False so dec k by 462 to get 3183.0
# w <= 1076 evals to 1068.0 <= 1076 and is True so inc nkr by 874 to get -2483.0
# ghj == -776 evals to -776.0 == -776 and is True so inc qrc by -180 to get -3999.0
# rlq == 801 evals to 801.0 == 801 and is True so inc qn by 812 to get 4441.0
# qn >= 4437 evals to 4441.0 >= 4437 and is True so inc afu by 297 to get 1125.0
# pr >= -5170 evals to -5177.0 >= -5170 and is False so dec wfk by 497 to get -1320.0
# vh == 169 evals to 164.0 == 169 and is False so dec ghj by -805 to get -776.0
# bfx == 2704 evals to 2704.0 == 2704 and is True so inc sh by 655 to get -411.0
# nkr < -2476 evals to -2483.0 < -2476 and is True so dec lpi by -494 to get -1439.0
# pr > -5181 evals to -5177.0 > -5181 and is True so dec nkr by -53 to get -2430.0
# nkr == -2430 evals to -2430.0 == -2430 and is True so dec jq by -486 to get 3934.0
# sh <= -407 evals to -411.0 <= -407 and is True so dec vh by 708 to get -544.0
# k == 3183 evals to 3183.0 == 3183 and is True so dec fkp by -260 to get 2440.0
# g == -1429 evals to -1424.0 == -1429 and is False so dec rlq by -629 to get 801.0
# m == 41 evals to 41.0 == 41 and is True so inc nkr by -863 to get -3293.0
# k >= 3180 evals to 3183.0 >= 3180 and is True so inc k by 897 to get 4080.0
# afu >= 1122 evals to 1125.0 >= 1122 and is True so dec u by -471 to get -1458.0
# afu != 1134 evals to 1125.0 != 1134 and is True so dec yo by 460 to get -3647.0
# k > 4073 evals to 4080.0 > 4073 and is True so inc ghj by 211 to get -565.0
# vh < -535 evals to -544.0 < -535 and is True so dec jq by -10 to get 3944.0
# pr != -5167 evals to -5177.0 != -5167 and is True so inc afu by -526 to get 599.0
# wfk != -1319 evals to -1320.0 != -1319 and is True so inc qdq by 399 to get 2522.0
# t < -757 evals to -760.0 < -757 and is True so dec rlq by 426 to get 375.0
# bfx == 2698 evals to 2704.0 == 2698 and is False so inc ev by -292 to get -1692.0
# qdq <= 2513 evals to 2522.0 <= 2513 and is False so inc vh by -345 to get -544.0
# k != 4083 evals to 4080.0 != 4083 and is True so dec jq by -722 to get 4666.0
# sh == -411 evals to -411.0 == -411 and is True so dec w by -15 to get 1083.0
# lpi == -1439 evals to -1439.0 == -1439 and is True so dec m by -191 to get 232.0
# jh >= -2780 evals to -2777.0 >= -2780 and is True so inc t by -72 to get -832.0
# jh != -2777 evals to -2777.0 != -2777 and is False so inc sh by -664 to get -411.0
# jh > -2784 evals to -2777.0 > -2784 and is True so inc lpi by 647 to get -792.0
# afu == 599 evals to 599.0 == 599 and is True so inc k by -651 to get 3429.0
# nkr < -3287 evals to -3293.0 < -3287 and is True so inc a by -431 to get -1255.0
# g <= -1418 evals to -1424.0 <= -1418 and is True so dec pr by 254 to get -5431.0
# ev >= -1683 evals to -1692.0 >= -1683 and is False so inc bfx by 288 to get 2704.0
# wfk < -1327 evals to -1320.0 < -1327 and is False so inc jh by -473 to get -2777.0
# qdq < 2529 evals to 2522.0 < 2529 and is True so dec jq by 871 to get 3795.0
# bfx < 2709 evals to 2704.0 < 2709 and is True so dec jq by 206 to get 3589.0
# vh <= -535 evals to -544.0 <= -535 and is True so inc m by 829 to get 1061.0
# qrc <= -3995 evals to -3999.0 <= -3995 and is True so dec qrc by 412 to get -4411.0
# wfk > -1323 evals to -1320.0 > -1323 and is True so dec g by -881 to get -543.0
# u >= -1448 evals to -1458.0 >= -1448 and is False so dec qn by -999 to get 4441.0
# u >= -1459 evals to -1458.0 >= -1459 and is True so inc ghj by -807 to get -1372.0
# sh > -421 evals to -411.0 > -421 and is True so dec rlq by -967 to get 1342.0
# vh < -536 evals to -544.0 < -536 and is True so inc rlq by -608 to get 734.0
# bfx != 2702 evals to 2704.0 != 2702 and is True so inc t by -686 to get -1518.0
# t >= -1520 evals to -1518.0 >= -1520 and is True so inc yo by -228 to get -3875.0
# afu > 597 evals to 599.0 > 597 and is True so inc a by 650 to get -605.0
# fkp > 2436 evals to 2440.0 > 2436 and is True so dec sh by -918 to get 507.0
# jq == 3589 evals to 3589.0 == 3589 and is True so inc m by 210 to get 1271.0
# vh > -535 evals to -544.0 > -535 and is False so dec wfk by -634 to get -1320.0
# pr < -5427 evals to -5431.0 < -5427 and is True so inc t by -360 to get -1878.0
# k > 3424 evals to 3429.0 > 3424 and is True so inc m by 899 to get 2170.0
# jq < 3594 evals to 3589.0 < 3594 and is True so dec afu by -768 to get 1367.0
# ghj == -1372 evals to -1372.0 == -1372 and is True so inc rlq by -990 to get -256.0
# pr < -5438 evals to -5431.0 < -5438 and is False so inc t by -859 to get -1878.0
# jq == 3589 evals to 3589.0 == 3589 and is True so inc lpi by -961 to get -1753.0
# rlq != -248 evals to -256.0 != -248 and is True so dec bfx by -476 to get 3180.0
# ev > -1697 evals to -1692.0 > -1697 and is True so dec lpi by -238 to get -1515.0
# jh >= -2782 evals to -2777.0 >= -2782 and is True so dec yo by -634 to get -3241.0
# jh != -2774 evals to -2777.0 != -2774 and is True so inc a by -111 to get -716.0
# bfx < 3185 evals to 3180.0 < 3185 and is True so inc bfx by 805 to get 3985.0
# jh <= -2771 evals to -2777.0 <= -2771 and is True so inc ghj by -497 to get -1869.0
# g == -543 evals to -543.0 == -543 and is True so inc sh by 496 to get 1003.0
# jh == -2777 evals to -2777.0 == -2777 and is True so dec ev by 555 to get -2247.0
# wfk >= -1320 evals to -1320.0 >= -1320 and is True so inc jq by -547 to get 3042.0
# rlq != -256 evals to -256.0 != -256 and is False so inc wfk by -489 to get -1320.0
# ev > -2242 evals to -2247.0 > -2242 and is False so dec sh by -212 to get 1003.0
# vh == -544 evals to -544.0 == -544 and is True so dec nkr by 890 to get -4183.0
# rlq == -256 evals to -256.0 == -256 and is True so inc t by 639 to get -1239.0
# jq != 3047 evals to 3042.0 != 3047 and is True so inc ghj by 397 to get -1472.0
# bfx <= 3992 evals to 3985.0 <= 3992 and is True so inc qn by -489 to get 3952.0
# a != -720 evals to -716.0 != -720 and is True so dec rlq by -359 to get 103.0
# t == -1239 evals to -1239.0 == -1239 and is True so inc u by -474 to get -1932.0
# jh != -2782 evals to -2777.0 != -2782 and is True so inc jh by 205 to get -2572.0
# lpi <= -1514 evals to -1515.0 <= -1514 and is True so inc t by -581 to get -1820.0
# afu <= 1370 evals to 1367.0 <= 1370 and is True so inc vh by -319 to get -863.0
# yo > -3248 evals to -3241.0 > -3248 and is True so dec w by 908 to get 175.0
# qdq < 2528 evals to 2522.0 < 2528 and is True so inc wfk by 333 to get -987.0
# afu < 1367 evals to 1367.0 < 1367 and is False so dec qn by -736 to get 3952.0
# t > -1824 evals to -1820.0 > -1824 and is True so dec afu by -208 to get 1575.0
# yo < -3237 evals to -3241.0 < -3237 and is True so inc bfx by -918 to get 3067.0
# lpi == -1515 evals to -1515.0 == -1515 and is True so dec a by -729 to get 13.0
# jh < -2577 evals to -2572.0 < -2577 and is False so dec u by -331 to get -1932.0
# ghj >= -1480 evals to -1472.0 >= -1480 and is True so inc pr by -364 to get -5795.0
# m != 2170 evals to 2170.0 != 2170 and is False so dec fkp by 48 to get 2440.0
# jq <= 3044 evals to 3042.0 <= 3044 and is True so inc rlq by 117 to get 220.0
# wfk == -987 evals to -987.0 == -987 and is True so dec qdq by 867 to get 1655.0
# w != 185 evals to 175.0 != 185 and is True so inc fkp by 17 to get 2457.0
# ghj <= -1472 evals to -1472.0 <= -1472 and is True so dec lpi by -5 to get -1510.0
# u >= -1934 evals to -1932.0 >= -1934 and is True so dec qrc by -512 to get -3899.0
# g < -534 evals to -543.0 < -534 and is True so dec nkr by -110 to get -4073.0
# nkr != -4076 evals to -4073.0 != -4076 and is True so dec afu by -42 to get 1617.0
# vh < -856 evals to -863.0 < -856 and is True so dec w by 538 to get -363.0
# wfk < -978 evals to -987.0 < -978 and is True so inc qrc by 248 to get -3651.0
# qn > 3955 evals to 3952.0 > 3955 and is False so inc qrc by -797 to get -3651.0
# jq > 3033 evals to 3042.0 > 3033 and is True so dec yo by -672 to get -2569.0
# qdq != 1655 evals to 1655.0 != 1655 and is False so inc a by 239 to get 13.0
# ev < -2247 evals to -2247.0 < -2247 and is False so dec rlq by -568 to get 220.0
# qn <= 3952 evals to 3952.0 <= 3952 and is True so dec g by 958 to get -1501.0
# wfk > -991 evals to -987.0 > -991 and is True so inc pr by 212 to get -5583.0
# pr < -5579 evals to -5583.0 < -5579 and is True so dec rlq by 674 to get -454.0
# sh > 998 evals to 1003.0 > 998 and is True so inc m by 605 to get 2775.0
# wfk <= -978 evals to -987.0 <= -978 and is True so dec qn by 575 to get 3377.0
# t == -1820 evals to -1820.0 == -1820 and is True so inc ghj by 599 to get -873.0
# lpi == -1510 evals to -1510.0 == -1510 and is True so dec jq by -170 to get 3212.0
# qrc > -3656 evals to -3651.0 > -3656 and is True so inc ev by -832 to get -3079.0
# ghj > -869 evals to -873.0 > -869 and is False so dec ev by 52 to get -3079.0
# ...
# a != 652 evals to 662.0 != 652 and is True so inc vh by -509 to get -2532.0
# ghj == -913 evals to -922.0 == -913 and is False so inc ghj by -904 to get -922.0
# ev > -2740 evals to -2737.0 > -2740 and is True so dec rlq by -727 to get -548.0
# wfk > -1475 evals to -1465.0 > -1475 and is True so inc vh by -752 to get -3284.0
# g == -1176 evals to -1176.0 == -1176 and is True so inc k by 252 to get 3008.0
# g == -1176 evals to -1176.0 == -1176 and is True so dec qrc by -220 to get -2853.0
# afu > 1314 evals to 1319.0 > 1314 and is True so inc rlq by 850 to get 302.0
# jh >= -3589 evals to -3584.0 >= -3589 and is True so dec ghj by 256 to get -1178.0
# qdq < -1750 evals to -1752.0 < -1750 and is True so dec u by -644 to get -963.0
# k != 3018 evals to 3008.0 != 3018 and is True so dec qrc by -156 to get -2697.0
# lpi < -2013 evals to -2017.0 < -2013 and is True so dec pr by 540 to get -6238.0
# t == -3086 evals to -3083.0 == -3086 and is False so inc lpi by -138 to get -2017.0
# ev == -2737 evals to -2737.0 == -2737 and is True so inc w by -935 to get 953.0
# lpi > -2019 evals to -2017.0 > -2019 and is True so inc qn by -507 to get 3846.0
# yo == -3390 evals to -3386.0 == -3390 and is False so inc qn by -951 to get 3846.0
# jh > -3591 evals to -3584.0 > -3591 and is True so inc qdq by -264 to get -2016.0
# u > -965 evals to -963.0 > -965 and is True so dec wfk by -87 to get -1378.0
# nkr < -6029 evals to -6034.0 < -6029 and is True so dec qn by -130 to get 3976.0
# t != -3076 evals to -3083.0 != -3076 and is True so inc g by -245 to get -1421.0
# qdq < -2013 evals to -2016.0 < -2013 and is True so inc jq by 992 to get 4510.0
# g <= -1416 evals to -1421.0 <= -1416 and is True so inc wfk by 169 to get -1209.0
# qdq != -2016 evals to -2016.0 != -2016 and is False so dec m by -822 to get 2183.0
# pr > -6233 evals to -6238.0 > -6233 and is False so dec vh by -900 to get -3284.0
# sh >= 670 evals to 674.0 >= 670 and is True so inc ghj by -57 to get -1235.0
# pr <= -6229 evals to -6238.0 <= -6229 and is True so dec ev by -617 to get -2120.0
# w != 958 evals to 953.0 != 958 and is True so inc t by -284 to get -3367.0
# sh > 664 evals to 674.0 > 664 and is True so dec fkp by 148 to get 4139.0
# yo < -3385 evals to -3386.0 < -3385 and is True so dec jq by 813 to get 3697.0
# m >= 2181 evals to 2183.0 >= 2181 and is True so inc sh by 582 to get 1256.0
# vh == -3284 evals to -3284.0 == -3284 and is True so inc k by -737 to get 2271.0
# sh < 1250 evals to 1256.0 < 1250 and is False so dec rlq by 133 to get 302.0
# ev < -2114 evals to -2120.0 < -2114 and is True so dec nkr by 990 to get -7024.0
# jh < -3574 evals to -3584.0 < -3574 and is True so dec lpi by 144 to get -2161.0
# rlq <= 302 evals to 302.0 <= 302 and is True so dec a by -303 to get 965.0
# jh == -3583 evals to -3584.0 == -3583 and is False so inc qdq by 140 to get -2016.0
# qn != 3976 evals to 3976.0 != 3976 and is False so dec wfk by -274 to get -1209.0
# ev > -2129 evals to -2120.0 > -2129 and is True so dec qrc by 982 to get -3679.0
# a <= 956 evals to 965.0 <= 956 and is False so dec a by 118 to get 965.0
# k >= 2263 evals to 2271.0 >= 2263 and is True so inc bfx by 302 to get 2969.0
# ghj != -1238 evals to -1235.0 != -1238 and is True so dec rlq by 286 to get 16.0
# nkr <= -7017 evals to -7024.0 <= -7017 and is True so inc vh by -79 to get -3363.0
# u > -972 evals to -963.0 > -972 and is True so dec m by -151 to get 2334.0
# w == 953 evals to 953.0 == 953 and is True so dec jh by -165 to get -3419.0
# fkp != 4129 evals to 4139.0 != 4129 and is True so inc fkp by -879 to get 3260.0
# fkp >= 3267 evals to 3260.0 >= 3267 and is False so dec t by -926 to get -3367.0
# rlq > 14 evals to 16.0 > 14 and is True so inc rlq by 659 to get 675.0
# bfx <= 2977 evals to 2969.0 <= 2977 and is True so dec qrc by -879 to get -2800.0
# fkp <= 3265 evals to 3260.0 <= 3265 and is True so dec pr by -568 to get -5670.0
# t == -3367 evals to -3367.0 == -3367 and is True so dec ghj by 941 to get -2176.0
# jh <= -3411 evals to -3419.0 <= -3411 and is True so inc m by 852 to get 3186.0
# nkr == -7024 evals to -7024.0 == -7024 and is True so inc k by 781 to get 3052.0
# rlq < 681 evals to 675.0 < 681 and is True so dec fkp by -731 to get 3991.0
# u == -957 evals to -963.0 == -957 and is False so inc w by -147 to get 953.0
# k == 3052 evals to 3052.0 == 3052 and is True so inc vh by 928 to get -2435.0
# qdq != -2015 evals to -2016.0 != -2015 and is True so inc t by -993 to get -4360.0
# wfk != -1216 evals to -1209.0 != -1216 and is True so inc u by 920 to get -43.0
# pr != -5673 evals to -5670.0 != -5673 and is True so dec qrc by -891 to get -1909.0
# fkp > 3985 evals to 3991.0 > 3985 and is True so inc rlq by 195 to get 870.0
# rlq >= 861 evals to 870.0 >= 861 and is True so dec jq by 837 to get 2860.0
# pr == -5670 evals to -5670.0 == -5670 and is True so inc nkr by -784 to get -7808.0
# w < 963 evals to 953.0 < 963 and is True so inc u by 873 to get 830.0
# rlq == 870 evals to 870.0 == 870 and is True so dec t by -903 to get -3457.0
# jq != 2851 evals to 2860.0 != 2851 and is True so inc qn by 751 to get 4727.0
# bfx != 2971 evals to 2969.0 != 2971 and is True so inc jh by 591 to get -2828.0
# m < 3187 evals to 3186.0 < 3187 and is True so dec wfk by -608 to get -601.0
# qdq != -2012 evals to -2016.0 != -2012 and is True so inc rlq by 16 to get 886.0
# t <= -3452 evals to -3457.0 <= -3452 and is True so inc qn by -188 to get 4539.0
# m < 3187 evals to 3186.0 < 3187 and is True so inc vh by -24 to get -2459.0
# rlq < 888 evals to 886.0 < 888 and is True so dec ev by -614 to get -1506.0
# qdq <= -2014 evals to -2016.0 <= -2014 and is True so inc a by -889 to get 76.0
# m < 3189 evals to 3186.0 < 3189 and is True so dec qn by -268 to get 4807.0
# afu <= 1319 evals to 1319.0 <= 1319 and is True so dec yo by 881 to get -4267.0
# qdq < -2006 evals to -2016.0 < -2006 and is True so inc rlq by -157 to get 729.0
# afu >= 1311 evals to 1319.0 >= 1311 and is True so dec pr by -159 to get -5511.0
# fkp == 3990 evals to 3991.0 == 3990 and is False so dec ev by 780 to get -1506.0
# bfx <= 2974 evals to 2969.0 <= 2974 and is True so dec yo by -893 to get -3374.0
# m <= 3189 evals to 3186.0 <= 3189 and is True so inc w by 62 to get 1015.0
# qdq == -2016 evals to -2016.0 == -2016 and is True so inc w by 876 to get 1891.0
# g >= -1426 evals to -1421.0 >= -1426 and is True so inc w by -860 to get 1031.0
# lpi < -2167 evals to -2161.0 < -2167 and is False so dec t by -819 to get -3457.0
# ghj != -2184 evals to -2176.0 != -2184 and is True so inc g by -258 to get -1679.0
# ghj > -2184 evals to -2176.0 > -2184 and is True so dec bfx by -116 to get 3085.0
# m >= 3182 evals to 3186.0 >= 3182 and is True so inc yo by -995 to get -4369.0
# vh == -2459 evals to -2459.0 == -2459 and is True so dec vh by -479 to get -1980.0
# yo == -4369 evals to -4369.0 == -4369 and is True so inc g by 896 to get -783.0
# w < 1029 evals to 1031.0 < 1029 and is False so inc ghj by -594 to get -2176.0
# g > -786 evals to -783.0 > -786 and is True so dec jh by -204 to get -2624.0
# rlq >= 729 evals to 729.0 >= 729 and is True so inc jh by -320 to get -2944.0
# u < 840 evals to 830.0 < 840 and is True so inc wfk by 699 to get 98.0
# sh < 1248 evals to 1256.0 < 1248 and is False so dec nkr by -785 to get -7808.0
# k <= 3061 evals to 3052.0 <= 3061 and is True so inc ev by -21 to get -1527.0
# jq >= 2860 evals to 2860.0 >= 2860 and is True so dec k by -540 to get 3592.0
# a != 76 evals to 76.0 != 76 and is False so dec a by 282 to get 76.0
# fkp == 3990 evals to 3991.0 == 3990 and is False so dec ev by 320 to get -1527.0
# k != 3588 evals to 3592.0 != 3588 and is True so dec ghj by -655 to get -1521.0
# sh < 1263 evals to 1256.0 < 1263 and is True so inc nkr by 31 to get -7777.0
# qn != 4807 evals to 4807.0 != 4807 and is False so dec qrc by 182 to get -1909.0
# k > 3590 evals to 3592.0 > 3590 and is True so dec wfk by 453 to get -355.0
# yo >= -4376 evals to -4369.0 >= -4376 and is True so inc fkp by -535 to get 3456.0
# rlq == 729 evals to 729.0 == 729 and is True so inc qn by -304 to get 4503.0
# t != -3453 evals to -3457.0 != -3453 and is True so inc jh by 46 to get -2898.0
# bfx == 3085 evals to 3085.0 == 3085 and is True so dec rlq by -90 to get 819.0
# m == 3186 evals to 3186.0 == 3186 and is True so inc u by -448 to get 382.0
# jq == 2860 evals to 2860.0 == 2860 and is True so inc bfx by -855 to get 2230.0
# bfx < 2231 evals to 2230.0 < 2231 and is True so inc lpi by 574 to get -1587.0
# vh < -1974 evals to -1980.0 < -1974 and is True so dec qdq by -247 to get -1769.0
# qrc <= -1911 evals to -1909.0 <= -1911 and is False so dec pr by 795 to get -5511.0
# u == 382 evals to 382.0 == 382 and is True so dec rlq by -363 to get 1182.0
# g >= -780 evals to -783.0 >= -780 and is False so dec wfk by 924 to get -355.0
# lpi >= -1593 evals to -1587.0 >= -1593 and is True so inc u by 883 to get 1265.0
# ghj == -1521 evals to -1521.0 == -1521 and is True so inc w by 819 to get 1850.0
# lpi > -1593 evals to -1587.0 > -1593 and is True so dec sh by 299 to get 957.0
# a != 76 evals to 76.0 != 76 and is False so dec bfx by 677 to get 2230.0
# fkp > 3447 evals to 3456.0 > 3447 and is True so dec lpi by -513 to get -1074.0
# w > 1841 evals to 1850.0 > 1841 and is True so dec ghj by 149 to get -1670.0
# fkp == 3456 evals to 3456.0 == 3456 and is True so dec rlq by 760 to get 422.0
# vh == -1980 evals to -1980.0 == -1980 and is True so inc jh by -371 to get -3269.0
# w < 1851 evals to 1850.0 < 1851 and is True so inc fkp by -613 to get 2843.0
# qrc != -1912 evals to -1909.0 != -1912 and is True so inc ev by -657 to get -2184.0
# k < 3597 evals to 3592.0 < 3597 and is True so inc qdq by -594 to get -2363.0
# qdq < -2354 evals to -2363.0 < -2354 and is True so inc fkp by -974 to get 1869.0
# jq >= 2870 evals to 2860.0 >= 2870 and is False so dec fkp by -797 to get 1869.0
# sh <= 957 evals to 957.0 <= 957 and is True so dec jh by 131 to get -3400.0
# fkp >= 1861 evals to 1869.0 >= 1861 and is True so dec lpi by 350 to get -1424.0
# afu != 1312 evals to 1319.0 != 1312 and is True so dec ghj by -888 to get -782.0
# jq >= 2859 evals to 2860.0 >= 2859 and is True so inc rlq by 43 to get 465.0
# a > 69 evals to 76.0 > 69 and is True so inc u by 604 to get 1869.0
# qrc != -1909 evals to -1909.0 != -1909 and is False so inc jq by -490 to get 2860.0
# a >= 74 evals to 76.0 >= 74 and is True so inc w by -816 to get 1034.0
# rlq > 467 evals to 465.0 > 467 and is False so inc afu by 3 to get 1319.0
# jq <= 2866 evals to 2860.0 <= 2866 and is True so dec yo by 688 to get -5057.0
# qn < 4506 evals to 4503.0 < 4506 and is True so dec jh by 134 to get -3534.0
# ghj > -788 evals to -782.0 > -788 and is True so dec afu by -838 to get 2157.0
# qn < 4507 evals to 4503.0 < 4507 and is True so inc g by -201 to get -984.0
# m <= 3188 evals to 3186.0 <= 3188 and is True so inc qn by 216 to get 4719.0
# qn < 4729 evals to 4719.0 < 4729 and is True so inc qdq by -311 to get -2674.0
# fkp > 1860 evals to 1869.0 > 1860 and is True so inc qrc by -418 to get -2327.0
# qrc <= -2326 evals to -2327.0 <= -2326 and is True so dec yo by 109 to get -5166.0
# jq == 2854 evals to 2860.0 == 2854 and is False so dec qrc by 29 to get -2327.0
# m <= 3187 evals to 3186.0 <= 3187 and is True so inc yo by -110 to get -5276.0
# wfk == -355 evals to -355.0 == -355 and is True so inc k by 80 to get 3672.0
# ghj > -788 evals to -782.0 > -788 and is True so inc ghj by -195 to get -977.0
# w != 1044 evals to 1034.0 != 1044 and is True so dec lpi by 758 to get -2182.0
# fkp >= 1866 evals to 1869.0 >= 1866 and is True so dec jh by -573 to get -2961.0
# qrc == -2327 evals to -2327.0 == -2327 and is True so inc rlq by 35 to get 500.0
# lpi <= -2175 evals to -2182.0 <= -2175 and is True so dec pr by -990 to get -4521.0
# vh > -1985 evals to -1980.0 > -1985 and is True so inc wfk by -456 to get -811.0
# a > 72 evals to 76.0 > 72 and is True so inc rlq by 631 to get 1131.0
# k <= 3678 evals to 3672.0 <= 3678 and is True so inc yo by 116 to get -5160.0
# qdq <= -2667 evals to -2674.0 <= -2667 and is True so inc g by 85 to get -899.0
# g >= -903 evals to -899.0 >= -903 and is True so dec ev by -75 to get -2109.0
# lpi > -2184 evals to -2182.0 > -2184 and is True so dec ev by -646 to get -1463.0
# afu > 2154 evals to 2157.0 > 2154 and is True so dec nkr by 870 to get -8647.0
# m < 3189 evals to 3186.0 < 3189 and is True so inc jq by -53 to get 2807.0
# nkr < -8646 evals to -8647.0 < -8646 and is True so dec afu by 611 to get 1546.0
# g < -897 evals to -899.0 < -897 and is True so dec m by -287 to get 3473.0
# a < 85 evals to 76.0 < 85 and is True so inc nkr by 36 to get -8611.0
# vh > -1982 evals to -1980.0 > -1982 and is True so inc nkr by 54 to get -8557.0
# g < -894 evals to -899.0 < -894 and is True so inc wfk by 109 to get -702.0
# afu <= 1553 evals to 1546.0 <= 1553 and is True so dec afu by 439 to get 1107.0
# ghj == -977 evals to -977.0 == -977 and is True so inc bfx by 471 to get 2701.0
# w >= 1027 evals to 1034.0 >= 1027 and is True so inc nkr by 76 to get -8481.0
# yo <= -5160 evals to -5160.0 <= -5160 and is True so inc m by 420 to get 3893.0
# a <= 79 evals to 76.0 <= 79 and is True so dec u by 379 to get 1490.0
# lpi == -2182 evals to -2182.0 == -2182 and is True so dec g by -318 to get -581.0
# g == -581 evals to -581.0 == -581 and is True so dec rlq by -827 to get 1958.0
# fkp >= 1869 evals to 1869.0 >= 1869 and is True so inc vh by 985 to get -995.0
# ghj >= -979 evals to -977.0 >= -979 and is True so dec afu by 451 to get 656.0
# qdq < -2678 evals to -2674.0 < -2678 and is False so dec m by 366 to get 3893.0
# yo == -5160 evals to -5160.0 == -5160 and is True so dec yo by -144 to get -5016.0
# m > 3889 evals to 3893.0 > 3889 and is True so inc t by -342 to get -3799.0
# m <= 3900 evals to 3893.0 <= 3900 and is True so inc k by 351 to get 4023.0
# rlq >= 1955 evals to 1958.0 >= 1955 and is True so inc nkr by 232 to get -8249.0
# qn != 4715 evals to 4719.0 != 4715 and is True so inc afu by -56 to get 600.0
# sh <= 959 evals to 957.0 <= 959 and is True so inc qdq by 964 to get -1710.0
# pr != -4520 evals to -4521.0 != -4520 and is True so inc qn by -818 to get 3901.0
# afu > 592 evals to 600.0 > 592 and is True so inc qrc by -291 to get -2618.0
# g < -577 evals to -581.0 < -577 and is True so inc t by 121 to get -3678.0
# u >= 1485 evals to 1490.0 >= 1485 and is True so inc rlq by -364 to get 1594.0
# vh < -1002 evals to -995.0 < -1002 and is False so dec u by -730 to get 1490.0
# rlq <= 1598 evals to 1594.0 <= 1598 and is True so dec qrc by 612 to get -3230.0
# t == -3678 evals to -3678.0 == -3678 and is True so inc g by -540 to get -1121.0
# wfk == -702 evals to -702.0 == -702 and is True so dec rlq by 717 to get 877.0
# jh <= -2952 evals to -2961.0 <= -2952 and is True so dec wfk by 501 to get -1203.0
# qdq >= -1712 evals to -1710.0 >= -1712 and is True so dec qn by 502 to get 3399.0
# m >= 3891 evals to 3893.0 >= 3891 and is True so dec qdq by -30 to get -1680.0
# nkr < -8246 evals to -8249.0 < -8246 and is True so inc qn by 962 to get 4361.0
# jh > -2970 evals to -2961.0 > -2970 and is True so inc m by 270 to get 4163.0
# yo == -5024 evals to -5016.0 == -5024 and is False so dec wfk by 872 to get -1203.0
# lpi <= -2181 evals to -2182.0 <= -2181 and is True so dec yo by 872 to get -5888.0
# jq >= 2812 evals to 2807.0 >= 2812 and is False so inc bfx by 552 to get 2701.0
# vh > -998 evals to -995.0 > -998 and is True so inc fkp by -443 to get 1426.0
# vh >= -992 evals to -995.0 >= -992 and is False so inc nkr by 571 to get -8249.0
# qdq >= -1682 evals to -1680.0 >= -1682 and is True so dec vh by -465 to get -530.0
# nkr < -8246 evals to -8249.0 < -8246 and is True so inc u by 613 to get 2103.0
# rlq < 880 evals to 877.0 < 880 and is True so inc nkr by 63 to get -8186.0
# sh == 957 evals to 957.0 == 957 and is True so inc qn by -430 to get 3931.0
# pr > -4530 evals to -4521.0 > -4530 and is True so inc qrc by -495 to get -3725.0
# w == 1034 evals to 1034.0 == 1034 and is True so inc vh by 229 to get -301.0
# jq >= 2801 evals to 2807.0 >= 2801 and is True so inc bfx by 184 to get 2885.0
# lpi <= -2192 evals to -2182.0 <= -2192 and is False so inc jq by -41 to get 2807.0
# wfk < -1202 evals to -1203.0 < -1202 and is True so dec afu by 990 to get -390.0

# %%
current_amt
# Out:
# {'a': 76.0,
#  'afu': -390.0,
#  'bfx': 2885.0,
#  'ev': -1463.0,
#  'fkp': 1426.0,
#  'g': -1121.0,
#  'ghj': -977.0,
#  'jh': -2961.0,
#  'jq': 2807.0,
#  'k': 4023.0,
#  'lpi': -2182.0,
#  'm': 4163.0,
#  'nkr': -8186.0,
#  'pr': -4521.0,
#  'qdq': -1680.0,
#  'qn': 3931.0,
#  'qrc': -3725.0,
#  'rlq': 877.0,
#  'sh': 957.0,
#  't': -3678.0,
#  'u': 2103.0,
#  'vh': -301.0,
#  'w': 1034.0,
#  'wfk': -1203.0,
#  'yo': -5888.0}

# %%
max(current_amt.values())
# Out:
# 4163.0

# %% [markdown]
# That's the right answer! You are one gold star closer to debugging the printer.

# %% [markdown]
# --- Part Two ---
#
# To be safe, the CPU also needs to know the highest value held in any register during this process so that it can decide how much memory to allocate to these operations. For example, in the above instructions, the highest value ever held was 10 (in register c after the third instruction was evaluated).

# %%
# copied output above to text file
with open("day8_output.txt") as f:
    results = f.readlines()

# %%
results[0:5]
# Out:
# ['bfx > -10 evals to 0 > -10 and is True so dec g by 231 to get -231.0\n',
#  'wfk == 0 evals to 0 == 0 and is True so dec k by -567 to get 567.0\n',
#  'a < 2 evals to 0 < 2 and is True so inc jq by 880 to get 880.0\n',
#  'nkr < -5 evals to 0 < -5 and is False so inc sh by -828 to get 0\n',
#  'nkr > -10 evals to 0 > -10 and is True so inc w by 595 to get 595.0\n']

# %%
running_vals = [float(x.strip("\n").split()[-1]) for x in results]

# %%
running_vals[0:5]
# Out:
# [-231.0, 567.0, 880.0, 0.0, 595.0]

# %%
max(running_vals)
# Out:
# 5347.0

# %% [markdown]
# That's the right answer! You are one gold star closer to debugging the printer.
