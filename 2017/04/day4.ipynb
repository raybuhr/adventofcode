# %%
import os

with open('input.txt') as f:
    lines = f.readlines()

# %%
line_lengths = [len(x.strip("\n").split(" ")) for x in lines]
uniq_lengths = [len(set(x.strip("\n").split(" "))) for x in lines]

# %%
line_lengths[0:5]
# Out:
# [6, 8, 8, 6, 9]

# %%
uniq_lengths[0:5]
# Out:
# [6, 8, 8, 6, 9]

# %%
valid_passwords = [1 for x in range(len(line_lengths)) if line_lengths[x] == uniq_lengths[x]]
print(sum(valid_passwords))
# Out:
# 455

# %% [markdown]
# That's the right answer! You are one gold star closer to debugging the printer.

# %% [markdown]
# --- Part Two ---
#
# For added security, yet another system policy has been put in place. Now, a valid passphrase must contain no two words that are anagrams of each other - that is, a passphrase is invalid if any word's letters can be rearranged to form any other word in the passphrase.
#
# For example:
#
# abcde fghij is a valid passphrase.
# abcde xyz ecdab is not valid - the letters from the third word can be rearranged to form the first word.
# a ab abc abd abf abj is a valid passphrase, because all letters need to be used when forming another word.
# iiii oiii ooii oooi oooo is valid.
# oiii ioii iioi iiio is not valid - any of these words can be rearranged to form any other word.
# Under this new system policy, how many passphrases are valid?

# %%
import pandas as pd

# %%
passwords = [x.strip("\n").split(" ") for x in lines]
df = pd.DataFrame({"words": passwords})

# %%
def has_anagram(word_list):
    new_list = [''.join(sorted(x)) for x in word_list]
    if len(set(new_list)) == len(word_list):
        return False
    else:
        return True

# %%
test_list = [''.join(sorted(x)) for x in passwords[0]]
test_list
# Out:
# ['bddjjow', 'acimrv', 'bcjjm', 'anr', 'flmmos', 'fiosv']

# %%
has_anagram(passwords[0])
# Out:
# False

# %%
df['has_anagram'] = df.words.apply(has_anagram)

# %%
df.sample(10)
# Out:
#                                                  words  has_anagram
# 262   [gxwrt, btmimse, dkpbha, idmz, mtignka, ngakmti]         True
# 32   [kjexme, gxbysxp, yxrum, hinrklv, fxehytd, qkt...         True
# 176             [vdqf, vdqf, ycjrg, ovzl, lelbe, vdqf]         True
# 491  [nvkbo, sgv, mquwb, ritpye, nbkov, poex, hraor...         True
# 256        [ibx, pfll, rgkp, nancij, llpf, xib, gbkfy]         True
# 35   [eregs, qdx, tdequa, agrlrg, mwwpba, qjie, yrj...        False
# 380                      [akq, nmlw, fupwsth, jduvhva]        False
# 281             [bkbazff, ldmaq, tyfl, acqurpy, ndnrp]        False
# 442  [ymruz, umzry, hbltwya, jhwhzk, flh, tahylbw, ...         True
# 443  [uxpato, owsqyao, vaog, oenomkc, usrmnc, epua,...        False

# %%
df.has_anagram.sum()
# Out:
# 326

# %%
def is_not_valid(word_list):
    unique_words = set(word_list)
    if len(unique_words) == len(word_list):
        return False
    else:
        return True

# %%
print(passwords[0])
is_not_valid(passwords[0])
# Out:
# ['bdwdjjo', 'avricm', 'cjbmj', 'ran', 'lmfsom', 'ivsof']
# False

# %%
df['not_valid'] = df.words.apply(is_not_valid)

# %%
df.sample(10)
# Out:
#                                                  words  has_anagram  not_valid
# 144  [ogr, uyuxdco, bpjgir, edztxv, sxtgu, jzfmx, i...        False      False
# 88           [jgrp, diu, jrgp, onjnml, nojmnl, vxockc]         True      False
# 449  [igjpn, wfy, ukn, aag, quro, wklsq, cjq, bgtjr...        False      False
# 87               [jtnp, cegdsoy, gfuvfbg, gdmn, ahlsc]        False      False
# 447  [jbzadnx, lzl, sdamer, okoico, frqisrm, lxet, ...        False      False
# 231  [psd, cyq, xpoyqny, yqc, kozqh, vonfd, uhozwz,...         True      False
# 380                      [akq, nmlw, fupwsth, jduvhva]        False      False
# 328   [rxx, ldqffi, ulappk, nltawbn, tplhb, kyb, cqyi]        False      False
# 423  [sua, itv, hfpg, bdqye, bznlrk, hfpg, bdqye, k...         True       True
# 157    [sypianq, yss, lmhu, ulmh, itilh, ndkda, lhiit]         True      False

# %%
df[(df.has_anagram == False) & (df.not_valid == False)]
# Out:
#                                                  words  has_anagram  not_valid
# 0         [bdwdjjo, avricm, cjbmj, ran, lmfsom, ivsof]        False      False
# 1    [mxonybc, fndyzzi, gmdp, gdfyoi, inrvhr, kpuue...        False      False
# 3        [fumay, zbccai, qymavw, zwoove, hqpd, rcxyvy]        False      False
# 4    [bcuo, khhkkro, mpt, dxrebym, qwum, zqp, lhmbm...        False      False
# 10   [wgt, gzi, icpwp, qeefgbe, msadakj, jbbrma, sb...        False      False
# 11   [cfzx, bvyu, eswr, hafcfy, klw, bgnhynv, qrf, ...        False      False
# 15   [mkzf, cat, tkjprc, izxdggf, obspan, lmlbg, bs...        False      False
# 17   [dxvnyd, nxwojj, arutn, eyqocj, swzao, tmh, ju...        False      False
# 18     [teu, eman, rlmdmk, xkbodv, fvrcm, zorgy, wmwe]        False      False
# 21   [rwbsay, alsi, bmzpvw, ozq, aduui, nihwx, glwd...        False      False
# 25   [uhbzmre, mpdxm, alkbmsq, aopjmkl, mqxenry, ay...        False      False
# 26                           [fimjr, ccv, cnug, crdsv]        False      False
# 33   [kywnux, wab, tzrft, dsaz, jgwuw, dubarmi, fle...        False      False
# 35   [eregs, qdx, tdequa, agrlrg, mwwpba, qjie, yrj...        False      False
# 39   [cqvl, rrcoqxs, staeuqr, hzzow, cwv, tsvol, di...        False      False
# 41      [uqkjmul, dour, zgq, ztango, yrrjhrg, ufxnmuw]        False      False
# 44                [zjlconc, osgsro, dajzo, hqih, ehml]        False      False
# 46   [xgbdeso, xiizs, omqwy, sbtnnt, khago, evviclw...        False      False
# 47   [cnzu, bia, vdyqrf, wwb, qveum, hmh, ouupgc, o...        False      False
# 60   [ocutdhz, zmnaap, llgv, llzpl, loavju, guzkfq,...        False      False
# 61       [etyzx, tcm, upxrtvd, imyoiu, rdpj, fed, dmm]        False      False
# 66   [vbjgql, yeshsuv, lokt, efqota, wpwjfu, ykyq, ...        False      False
# 69   [jsaq, hcww, iayqtu, llv, gdpxdrd, hwlo, nosji...        False      False
# 71             [grafa, hbb, ghk, wkdpsf, ufa, uoqmysd]        False      False
# 75                            [ljl, ryc, mrewrge, yky]        False      False
# 78                [uziil, xobutwf, acnof, iqgwl, diso]        False      False
# 80        [lajcp, qgiw, fyz, blrlcd, pviwv, buh, wnkk]        False      False
# 87               [jtnp, cegdsoy, gfuvfbg, gdmn, ahlsc]        False      False
# 90                [usuvoo, jkih, ylafyy, yhio, jureyj]        False      False
# 96   [macllv, ldl, kyluine, lbt, hbxbr, wxcaspp, ez...        False      False
# ..                                                 ...          ...        ...
# 434  [twtp, dvl, uvyje, qtlzj, dsvyr, qpjnj, eyoigx...        False      False
# 438  [ucsz, akswcd, ojrmqq, cox, hgfh, lxwu, ltnnf,...        False      False
# 440  [qojlkl, ircxqnt, utfmdg, fcvr, vehkcvt, ufmzc...        False      False
# 441  [rzkayeh, iursm, zhily, hdnq, fqydfvt, uwoy, h...        False      False
# 443  [uxpato, owsqyao, vaog, oenomkc, usrmnc, epua,...        False      False
# 445  [fjfgos, rmpd, mgs, vbk, dlls, jkljao, eoovdfb...        False      False
# 447  [jbzadnx, lzl, sdamer, okoico, frqisrm, lxet, ...        False      False
# 448                  [xceoqr, qai, vahc, jjzifsn, exg]        False      False
# 449  [igjpn, wfy, ukn, aag, quro, wklsq, cjq, bgtjr...        False      False
# 450              [fzlwnm, mygfn, vkzwvw, zvhsex, gfki]        False      False
# 451  [ijvzgai, ebmeq, wssfmbq, uguh, sfuutm, nwkgme...        False      False
# 452        [bjzkyjh, fced, nji, esowk, qxsubsk, qgtts]        False      False
# 455  [xpyew, xudfud, wwqe, qhfjlcu, epv, fnrbgyv, i...        False      False
# 458     [jjsagdl, umbpxre, kyre, zvaryft, tmw, pxpnjy]        False      False
# 468             [qpwq, exu, jvsiwj, gsw, avr, vbemldy]        False      False
# 473  [ewwyb, jidhu, pyvyenn, igtnyd, tiwr, akwkkbi,...        False      False
# 477  [mhjj, vjoa, gnjlc, kclcr, ito, ofksy, giavy, ...        False      False
# 478         [bkiqmif, izidbui, sttxxi, bswhkxp, sduuw]        False      False
# 485                    [snxj, szobqt, zcgvwv, wiyqknu]        False      False
# 486          [uto, jteikwd, cew, gqsks, hmvjtcy, sach]        False      False
# 487  [zpgl, qnkoex, amhufmr, figns, upv, xezrl, rjl...        False      False
# 492  [irxannd, fiud, ehyb, ggx, plqg, pvvn, uuptop,...        False      False
# 496           [zgk, gft, zybs, zrgcoo, ypu, bue, htgo]        False      False
# 497                     [xnesq, srsx, pkzaoh, cfqzugh]        False      False
# 499  [jsqq, tzwak, hephg, eqwczd, ioisa, yim, tmdif...        False      False
# 502     [ydeqf, bfaab, sydqhbp, smsxdjr, pynrs, cqymt]        False      False
# 506                       [xznvl, zwtdj, vbxdyd, clhw]        False      False
# 507             [hgy, zudelp, ickc, drfjgn, iyws, xhc]        False      False
# 508  [zzv, wik, iorhat, qkb, kjb, lykdz, vrce, yjsjwj]        False      False
# 509                            [gyw, xzgbi, efus, uuy]        False      False
#
# [186 rows x 3 columns]

# %% [markdown]
# That's the right answer! You are one gold star closer to debugging the printer.
#
# You have completed Day 4!
